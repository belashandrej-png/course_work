# %% [markdown]
# # Netflix Cash Flow Analysis
#
# ## Introduction
# This notebook performs comprehensive analysis of Netflix's cash flow statements.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.data_loader import DataLoader
from src.data_processor import DataProcessor
from src.visualizer import Visualizer

# %%
# Load data
loader = DataLoader(api_key='your_api_key')
data = loader.get_cash_flow_data('NFLX')

# %%
# Process data
processor = DataProcessor(data)
df = processor.process_annual_reports()
df.head()
